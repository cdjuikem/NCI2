# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_news",
  "q": "Vessel misreport catch",
  "api_key": "7020efc655aafd1998bfad82b8f96fee27be3cdb26c1bb67909ba7042c56ebd1"
}

search = GoogleSearch(params)
results = search.get_dict()
news_results = results["news_results"]

# %%
print(results)
# Out:
# {'search_metadata': {'id': '6675c9262d5b1251f204eb78', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/bc1435a4846664d1/6675c9262d5b1251f204eb78.json', 'created_at': '2024-06-21 18:40:38 UTC', 'processed_at': '2024-06-21 18:40:38 UTC', 'google_news_url': 'https://news.google.com/search?q=Vessel+misreport+catch&gl=US', 'raw_html_file': 'https://serpapi.com/searches/bc1435a4846664d1/6675c9262d5b1251f204eb78.html', 'total_time_taken': 7.08}, 'search_parameters': {'engine': 'google_news', 'gl': 'us', 'q': 'Vessel misreport catch'}, 'news_results': [{'position': 1, 'title': 'New rules tighten controls on EU vessels to prevent misreporting', 'source': {'name': 'Environmental Justice Foundation', 'icon': 'https://encrypted-tbn3.gstatic.com/faviconV2?url=https://ejfoundation.org&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'}, 'link': 'https://ejfoundation.org/news-media/new-rules-tighten-controls-on-eu-vessels-to-prevent-misreporting', 'thumbnail': 'ht
# ...

# %%
results = {'search_metadata': {'id': '66751ceb1988e5543a7f7660', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/bc1435a4846664d1/66751ceb1988e5543a7f7660.json', 'created_at': '2024-06-21 06:25:47 UTC', 'processed_at': '2024-06-21 06:25:47 UTC', 'google_news_url': 'https://news.google.com/search?q=Vessel+misreport+catch&gl=US', 'raw_html_file': 'https://serpapi.com/searches/bc1435a4846664d1/66751ceb1988e5543a7f7660.html', 'total_time_taken': 2.96}, 'search_parameters': {'engine': 'google_news', 'gl': 'us', 'q': 'Vessel misreport catch'}, 'news_results': [{'position': 1, 'title': 'New rules tighten controls on EU…', 'source': {'name': 'Environmental Justice Foundation', 'icon': 'https://encrypted-tbn3.gstatic.com/faviconV2?url=https://ejfoundation.org&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'}, 'link': 'https://ejfoundation.org/news-media/new-rules-tighten-controls-on-eu-vessels-to-prevent-misreporting', 'thumbnail': 'https://ejfoundation.org/resources/media/RS18209_DSC_0667.JPG', 'date': '05/24/2024, 07:00 AM, +0000 UTC'}, {'position': 2, 'title': 'Move the IUU Fight Up the Food Chain | Proceedings - November 2023 Vol. 149/11/1,449', 'source': {'name': 'USNI News', 'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.usni.org&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'}, 'link': 'https://www.usni.org/magazines/proceedings/2023/november/move-iuu-fight-food-chain', 'thumbnail': 'https://www.usni.org/sites/default/files/Sullivan-PRO-11-23%20Hero.jpg', 'date': '10/31/2023, 08:26 PM, +0000 UTC'}, {'position': 3, 'title': 'Surprise! Media is misreporting the source of a Dutch cargo ship fire', 'source': {'name': 'Electrek.co', 'icon': 'https://lh3.googleusercontent.com/l7Mfc9zmHOrMIQofQufvNr5A1UuFhQdUfYtN4WjTMdy3mZnJftPIR-NIzu8CuXH2WrsirIickA', 'authors': ['Jameson Dow']}, 'link': 'https://electrek.co/2023/07/26/surprise-media-is-misreporting-the-source-of-a-dutch-cargo-ship-fire/', 'thumbnail': 'https://electrek.co/wp-content/uploads/sites/3/2023/07/F18jgdCWYAE30NC-e1690369277647.jpeg?quality=82&strip=all', 'date': '07/26/2023, 07:00 AM, +0000 UTC'}, {'position': 4, 'title': 'Alaska fisherman given USD 1 million fine, jail-time for misreporting catch', 'source': {'name': 'SeafoodSource', 'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.seafoodsource.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL', 'authors': ['Brian Hagenbuch']}, 'link': 'https://www.seafoodsource.com/news/business-finance/alaska-fishermen-given-usd-1million-fine-jail-time-for-misreporting-catch', 'thumbnail': 'https://s3.divcom.com/www.seafoodsource.com/images/e9a6a645e4f794b5a931cc60f43a0911.jpg', 'date': '08/09/2021, 07:00 AM, +0000 UTC'}, {'position': 5, 'title': 'Report Finds Transshipments in Western and Central Pacific Likely Underreported', 'source': {'name': 'The Pew Charitable Trusts', 'icon': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.pewtrusts.org&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'}, 'link': 'https://www.pewtrusts.org/en/research-and-analysis/issue-briefs/2019/09/report-finds-transshipments-in-western-and-central-pacific-likely-underreported', 'thumbnail': 'https://www.pewtrusts.org/-/media/post-launch-images/2019/09/ldupewtuna130jpgmaster/16x9_m.jpg', 'date': '09/12/2019, 07:00 AM, +0000 UTC'}, {'position': 6, 'title': "NOAA, Coast Guard: More regs needed in wake of Rafael 's fraud", 'source': {'name': 'Fall River Herald News', 'icon': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.heraldnews.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'}, 'link': 'https://www.heraldnews.com/story/news/2019/12/04/noaa-coast-guard-more-regs/2155088007/', 'thumbnail': 'https://www.heraldnews.com/gcdn/authoring/2019/12/04/NHER/ghows-WL-98e31660-10d1-68e8-e053-0100007f0f63-e7d8bd84.jpeg?width=660&height=440&fit=crop&format=pjpg&auto=webp', 'date': '01/17/2022, 04:18 AM, +0000 UTC'}, {'position': 7, 'title': 'Three Fishing Companies and Five Vessel Masters Prosecuted for Misreporting', 'source': {'name': 'The Fishing Daily', 'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://thefishingdaily.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL', 'authors': ['Oliver McBride']}, 'link': 'https://thefishingdaily.com/latest-news/three-fishing-companies-and-five-vessel-masters-prosecuted-for-misreporting/', 'thumbnail': 'https://thefishingdaily.com/wp-content/uploads/2022/10/Guiding-Star-Photo-facebook.jpg', 'date': '06/23/2023, 07:00 AM, +0000 UTC'}, {'position': 8, 'title': 'Owner and crew of Maine herring seiner charged with misreporting landings', 'source': {'name': 'National Fisherman', 'icon': 'https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.nationalfisherman.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL', 'authors': ['Kirk Moore']}, 'link': 'https://www.nationalfisherman.com/northeast/owner-and-crew-of-maine-herring-seiner-charged-with-misreporting-landings', 'thumbnail': 'https://divcomplatformstaging.s3.amazonaws.com/nf-staging.divcomstaging.com/images/7941c5d1bff049637d79d69e78bd7c0a.jpeg', 'date': '01/31/2022, 08:00 AM, +0000 UTC'}, {'position': 9, 'title': 'What is Illegal, Unreported and Unregulated (IUU) Fishing?', 'source': {'name': 'EARTH.ORG', 'icon': 'https://lh3.googleusercontent.com/zKLjiD7tnD-LeHr3fr-boOPxNDQmRtv1NmiAsdCc7ro89ehmKJScTatI6nClHhLMfM8vLMCVKQ'}, 'link': 'https://earth.org/what-is-illegal-unreported-and-unregulated-iuu-fishing/', 'thumbnail': 'https://u4d2z7k9.rocketcdn.me/wp-content/uploads/2020/11/15903350173_112e28bc82_c.jpg', 'date': '11/27/2020, 08:00 AM, +0000 UTC'}, {'position': 10, 'title': '‘Phenomenal loophole’ in quotas could lead to massive overfishing', 'source': {'name': 'The Guardian', 'icon': 'https://lh3.googleusercontent.com/SU8FywVNtcrG-wgjvZ_0D1-3JR_pN9LNSgjULFH74N748KVyEdkF1jdbvP4Lr7_ClbPZxL-iPw', 'authors': ['Arthur Neslen']}, 'link': 'https://www.theguardian.com/environment/2023/mar/16/loophole-quotas-overfishing-endangered-species-eu-papers', 'thumbnail': 'https://i.guim.co.uk/img/media/d3ba5b24c86377af28862903d6751300fb6f4a01/0_255_4146_2488/master/4146.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctYWdlLTIwMjMucG5n&enable=upscale&s=088bf991e8ace689fa531c81fa419b84', 'date': '03/16/2023, 07:00 AM, +0000 UTC'}, {'position': 11, 'title': 'These animated maps track every large fishing boat in the world', 'source': {'name': 'Vox.com', 'icon': 'https://lh3.googleusercontent.com/Gg0cXcWKtjEfM_QT3nCzDrPhDP6mq4HDLESLpJJP2AeDzEFwctQi5h-EMSQk6wKta3PfaLz1bzU', 'authors': ['Brad Plumer']}, 'link': 'https://www.vox.com/2014/11/17/7234585/global-fishing-watch-maps', 'thumbnail': 'https://platform.vox.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/15067799/skytruth-gfw-world_atlantic-854x480.0.0.1446234345.jpg?quality=90&strip=all&crop=7.8454332552693,0,84.309133489461,100', 'date': '11/17/2014, 08:00 AM, +0000 UTC'}, {'position': 12, 'title': 'Stalemate over misreported catches persists in fisheries control revision', 'source': {'name': 'EURACTIV', 'icon': 'https://lh3.googleusercontent.com/AYlePk41Hl9JwJDoBfhkux6yFBlowekcQ4ql0DzRjCbRPceJhH9-w_d6pEQERQtU9dLk18lA', 'authors': ['Paula Andres']}, 'link': 'https://www.euractiv.com/section/agriculture-food/news/stalemate-over-misreported-catches-persists-in-fisheries-control-revision/', 'thumbnail': 'https://www.euractiv.com/wp-content/uploads/sites/2/2023/03/shutterstock_513364510-800x450.jpg', 'date': '03/13/2023, 07:00 AM, +0000 UTC'}, {'position': 13, 'title': "UPDATE: NOAA shuts down Rafael's fishing sector | News | gloucestertimes.com", 'source': {'name': 'Gloucester Daily Times', 'icon': 'https://encrypted-tbn3.gstatic.com/faviconV2?url=https://www.gloucestertimes.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL', 'authors': ['Sean Horgan']}, 'link': 'https://www.gloucestertimes.com/news/update-noaa-shuts-down-rafaels-fishing-sector/article_cfbb8ede-ce18-11e7-bec6-232fd290a9d7.html', 'thumbnail': 'https://bloximages.chicago2.vip.townnews.com/gloucestertimes.com/content/tncms/assets/v3/editorial/2/41/241c3956-ce19-11e7-a508-331433ca8d59/59f63e089d7b0.image.jpg?resize=400%2C269', 'date': '11/20/2017, 08:00 AM, +0000 UTC'}, {'position': 14, 'title': "Falklands' trawlers under investigation for alleged misreported catches", 'source': {'name': 'MercoPress', 'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://en.mercopress.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'}, 'link': 'https://en.mercopress.com/2015/07/25/falklands-trawlers-under-investigation-for-alleged-misreported-catches', 'thumbnail': 'https://en.mercopress.com/data/cache/noticias/51415/0x0/john-barton-falklands.jpg', 'date': '07/25/2015, 07:00 AM, +0000 UTC'}, {'position': 15, 'title': 'Did Japan fudge the truth about whaling?', 'source': {'name': 'The Japan Times', 'icon': 'https://lh3.googleusercontent.com/yWAxwMobqH3ST-hZJaptdmz7Yyf8WbHjosjtihsuHWr5dx69_uNzBgvAe5yCslHtI27571tM', 'authors': ['Rowan Hooper']}, 'link': 'https://www.japantimes.co.jp/news/2016/09/17/national/science-health/japan-fudge-truth-whaling/', 'thumbnail': 'https://www.japantimes.co.jp/wp-content/uploads/2016/09/p21-hooper-whaling-a-20160918.jpg', 'date': '09/17/2016, 07:00 AM, +0000 UTC'}, {'position': 16, 'title': "Criminality in Africa's Fishing Industry: A Threat to Human Security", 'source': {'name': 'Africa Center for Strategic Studies', 'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://africacenter.org&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL', 'authors': ['André Standing']}, 'link': 'https://africacenter.org/publication/criminality-africa-fishing-industry-threat-human-security/', 'thumbnail': 'https://africacenter.org/wp-content/uploads/2017/06/Illegal-fishing-scenario-tests-maritime-operations-1000x405.jpg', 'date': '06/06/2017, 07:00 AM, +0000 UTC'}, {'position': 17, 'title': 'Inaccurate EU catch reporting…', 'source': {'name': 'Environmental Justice Foundation', 'icon': 'https://encrypted-tbn3.gstatic.com/faviconV2?url=https://ejfoundation.org&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'}, 'link': 'https://ejfoundation.org/news-media/allowing-inaccurate-catch-reporting-will-endanger-fisheries-and-damage-eu-standing', 'thumbnail': 'https://ejfoundation.org/imager/media/121251/Fish-in-net_9573336b2a4ebbddc2e5c29eccbc1502.jpg', 'date': '02/03/2022, 08:00 AM, +0000 UTC'}, {'position': 18, 'title': 'Now you can watch every large fishing boat in the ocean (and a few illegal ones, too)', 'source': {'name': 'Vox.com', 'icon': 'https://lh3.googleusercontent.com/Gg0cXcWKtjEfM_QT3nCzDrPhDP6mq4HDLESLpJJP2AeDzEFwctQi5h-EMSQk6wKta3PfaLz1bzU', 'authors': ['Brad Plumer']}, 'link': 'https://www.vox.com/2016/9/16/12940708/global-fishing-watch', 'thumbnail': 'https://platform.vox.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/7113669/skytruth-gfw-world_atlantic-854x480.0.0.jpg?quality=90&strip=all&crop=7.8454332552693,0,84.309133489461,100', 'date': '09/16/2016, 07:00 AM, +0000 UTC'}, {'position': 19, 'title': 'Japan accused of falsifying whaling data', 'source': {'name': 'The Guardian', 'icon': 'https://lh3.googleusercontent.com/SU8FywVNtcrG-wgjvZ_0D1-3JR_pN9LNSgjULFH74N748KVyEdkF1jdbvP4Lr7_ClbPZxL-iPw', 'authors': ['Philip Francis Oldfield']}, 'link': 'https://www.theguardian.com/environment/2015/jul/15/japan-accused-of-falsifying-whaling-data', 'thumbnail': 'https://i.guim.co.uk/img/media/f83615293dca68e6501f4304df2a78180e2c7556/0_331_5187_3113/master/5187.jpg?width=465&dpr=1&s=none', 'date': '07/15/2015, 07:00 AM, +0000 UTC'}, {'position': 20, 'title': 'N.S. boat captain, 2 companies fined $125K for fisheries violations', 'source': {'name': 'CBC.ca', 'icon': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.cbc.ca&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL', 'authors': ['Paul Withers']}, 'link': 'https://www.cbc.ca/news/canada/nova-scotia/n-s-boat-captain-fined-fisheries-violations-1.6965198', 'thumbnail': 'https://i.cbc.ca/1.6438940.1694615489!/fileImage/httpImage/image.jpg_gen/derivatives/16x9_940/casey-henneberry.jpg', 'date': '09/13/2023, 07:00 AM, +0000 UTC'}, {'position': 21, 'title': 'Pacific-licensed vessels worst IUU fishers in the region', 'source': {'name': 'Loop PNG', 'icon': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.looppng.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'}, 'link': 'https://www.looppng.com/global-news/pacific-licensed-vessels-worst-iuu-fishers-region-110542', 'thumbnail': 'https://looppacificassets.s3.amazonaws.com/thumbnails/image/pacific-licensed_vessels_worst_iuu_fishers_in_the_region.jpeg', 'date': '03/10/2022, 08:00 AM, +0000 UTC'}, {'position': 22, 'title': 'Trawler captain dumped fish to save ship', 'source': {'name': 'Stuff', 'icon': 'https://lh3.googleusercontent.com/sNiuQLx7svAz3fVe_Pb4c1rAbyRSXe1ZxUT_lqWfYarSSPGoG1Sknvo0MKpeBaTJzPpCnjq2'}, 'link': 'https://www.stuff.co.nz/business/better-business/112621883/trawler-captain-dumped-fish-to-save-ship', 'thumbnail': 'https://www.stuff.co.nz/media/images/9Tzi8ywRz924XE3uHaD6DfGZQfjEdZd7oKlsiR53VLHvSZExpMzuRmKdwHbkL9Pk+ewodQcpBaB1hHz9sAlt2fUaL1Hcemr77bfUqbfQw+62MMr7AtZ1L3v+%2FzE+j9IeF44lrtgUFOkBXTRmj7GaPZAm8umK4T7%2Fqe0lloL%2FG+7oLzf+cIhkX%2FncvJ1t9Vfe?resolution=620x350', 'date': '05/09/2019, 07:00 AM, +0000 UTC'}, {'position': 23, 'title': 'NZDF boarded 26 vessels during Pacific fisheries patrols', 'source': {'name': 'CONTACT magazine', 'icon': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.contactairlandandsea.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'}, 'link': 'https://www.contactairlandandsea.com/2017/08/10/nzdf-pacific-fisheries-patrols/', 'thumbnail': 'https://www.contactairlandandsea.com/wp-content/uploads/2017/08/nzdf_fisheries_patrol-800x444.jpg', 'date': '08/10/2017, 07:00 AM, +0000 UTC'}, {'position': 24, 'title': 'Chinese boats fined $825k', 'source': {'name': 'The Fiji Times', 'icon': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.fijitimes.com.fj&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'}, 'link': 'https://www.fijitimes.com.fj/chinese-boats-fined-825k/', 'date': '06/24/2017, 07:00 AM, +0000 UTC'}, {'position': 25, 'title': 'Safety first – The National', 'source': {'name': 'The National', 'icon': 'https://encrypted-tbn2.gstatic.com/faviconV2?url=https://www.thenational.com.pg&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL'}, 'link': 'https://www.thenational.com.pg/safety-first-3/', 'thumbnail': 'https://i0.wp.com/www.thenational.com.pg/wp-content/uploads/2019/02/Fish.jpg?fit=640%2C426&ssl=1', 'date': '02/12/2019, 08:00 AM, +0000 UTC'}], 'menu_links': [{'title': 'U.S.', 'topic_token': 'CAAqIggKIhxDQkFTRHdvSkwyMHZNRGxqTjNjd0VnSmxiaWdBUAE', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_news&gl=us&topic_token=CAAqIggKIhxDQkFTRHdvSkwyMHZNRGxqTjNjd0VnSmxiaWdBUAE'}, {'title': 'World', 'topic_token': 'CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx1YlY4U0FtVnVHZ0pWVXlnQVAB', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_news&gl=us&topic_token=CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx1YlY4U0FtVnVHZ0pWVXlnQVAB'}, {'title': 'Your local news', 'topic_token': 'CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_news&gl=us&topic_token=CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE'}, {'title': 'Business', 'topic_token': 'CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx6TVdZU0FtVnVHZ0pWVXlnQVAB', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_news&gl=us&topic_token=CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx6TVdZU0FtVnVHZ0pWVXlnQVAB'}, {'title': 'Technology', 'topic_token': 'CAAqJggKIiBDQkFTRWdvSUwyMHZNRGRqTVhZU0FtVnVHZ0pWVXlnQVAB', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_news&gl=us&topic_token=CAAqJggKIiBDQkFTRWdvSUwyMHZNRGRqTVhZU0FtVnVHZ0pWVXlnQVAB'}, {'title': 'Entertainment', 'topic_token': 'CAAqJggKIiBDQkFTRWdvSUwyMHZNREpxYW5RU0FtVnVHZ0pWVXlnQVAB', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_news&gl=us&topic_token=CAAqJggKIiBDQkFTRWdvSUwyMHZNREpxYW5RU0FtVnVHZ0pWVXlnQVAB'}, {'title': 'Sports', 'topic_token': 'CAAqJggKIiBDQkFTRWdvSUwyMHZNRFp1ZEdvU0FtVnVHZ0pWVXlnQVAB', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_news&gl=us&topic_token=CAAqJggKIiBDQkFTRWdvSUwyMHZNRFp1ZEdvU0FtVnVHZ0pWVXlnQVAB'}, {'title': 'Science', 'topic_token': 'CAAqJggKIiBDQkFTRWdvSUwyMHZNRFp0Y1RjU0FtVnVHZ0pWVXlnQVAB', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_news&gl=us&topic_token=CAAqJggKIiBDQkFTRWdvSUwyMHZNRFp0Y1RjU0FtVnVHZ0pWVXlnQVAB'}, {'title': 'Health', 'topic_token': 'CAAqIQgKIhtDQkFTRGdvSUwyMHZNR3QwTlRFU0FtVnVLQUFQAQ', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_news&gl=us&topic_token=CAAqIQgKIhtDQkFTRGdvSUwyMHZNR3QwTlRFU0FtVnVLQUFQAQ'}]}

# %%
top_20 = results['news_results'][:20]
for item in top_20:
    print(item.keys())
    print(item['title'])
    print(item['link'])
# Out:
# dict_keys(['position', 'title', 'source', 'link', 'thumbnail', 'date'])
# New rules tighten controls on EU…
# https://ejfoundation.org/news-media/new-rules-tighten-controls-on-eu-vessels-to-prevent-misreporting
# dict_keys(['position', 'title', 'source', 'link', 'thumbnail', 'date'])
# Move the IUU Fight Up the Food Chain | Proceedings - November 2023 Vol. 149/11/1,449
# https://www.usni.org/magazines/proceedings/2023/november/move-iuu-fight-food-chain
# dict_keys(['position', 'title', 'source', 'link', 'thumbnail', 'date'])
# Surprise! Media is misreporting the source of a Dutch cargo ship fire
# https://electrek.co/2023/07/26/surprise-media-is-misreporting-the-source-of-a-dutch-cargo-ship-fire/
# dict_keys(['position', 'title', 'source', 'link', 'thumbnail', 'date'])
# Alaska fisherman given USD 1 million fine, jail-time for misreporting catch
# https://www.seafoodsource.com/news/business-finance/alaska-fishermen-given-usd-1million-fine-jail-time-for-misreporting-catch
# ...

# %% [markdown]
# ### News
# 76282857f01645c48802337b54e31e71
